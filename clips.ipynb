# %%
import os
import pandas as pd 

 
def main():
    df = pd.read_csv(r'C:\Users\yolos\Downloads\GradProject2 - Copy (2)\RecommendationSystem\dataWithCluster.csv')
    folder_path = r"C:\Users\yolos\Downloads\archive\fma_medium\fma_medium" #path of FMA_large
    output_folder = os.path.join(r"C:\Users\yolos\OneDrive\Desktop", "Recommendation")
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for folder_name in os.listdir(folder_path):
        folder_path = os.path.join(folder_path, folder_name)
        if os.path.isdir(folder_path):
            for filename in os.listdir(folder_path):
                if filename.endswith(".mp3"):
                    file_path = os.path.join(folder_path, filename)
                    track_id = int(filename[:-4].lstrip('0'))  # Get the track id from the filename
                    if track_id in df['track_id'].tolist():
                        # Move the mp3 file to the "Recommendation" folder
                        new_file_path = os.path.join(output_folder, filename)
                        os.rename(file_path, new_file_path)
                        print("Added:", filename)
                    else:
                        print("Ignored:", filename)
                        

    


main()
# Out:
# Ignored: 000002.mp3
# Ignored: 000003.mp3
# Ignored: 000136.mp3
# Ignored: 000148.mp3
# Ignored: 000181.mp3
# Ignored: 000182.mp3
# Ignored: 000424.mp3
# Ignored: 000425.mp3
# Ignored: 000458.mp3
# Ignored: 000459.mp3
# Ignored: 000512.mp3
# Ignored: 000590.mp3
# Ignored: 000591.mp3
# Ignored: 000592.mp3
# Ignored: 000593.mp3
# Ignored: 000615.mp3
# Ignored: 000666.mp3
# Ignored: 000667.mp3
# Ignored: 000668.mp3
# Ignored: 000672.mp3
# Ignored: 000674.mp3
# Ignored: 000676.mp3
# Ignored: 000680.mp3
# Ignored: 000684.mp3
# Ignored: 000686.mp3
# Ignored: 000696.mp3
# Ignored: 000698.mp3
# Ignored: 000701.mp3
# Ignored: 000702.mp3
# Ignored: 000703.mp3
# Ignored: 000704.mp3
# Ignored: 000705.mp3
# Ignored: 000706.mp3
# Ignored: 000707.mp3
# Ignored: 000708.mp3
# Ignored: 000709.mp3
# Ignored: 000734.mp3
# Ignored: 000735.mp3
# Ignored: 000736.mp3
# Ignored: 000737.mp3
# Ignored: 000738.mp3
# Ignored: 000739.mp3
# Ignored: 000740.mp3
# Ignored: 000741.mp3
# Ignored: 000742.mp3
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\yolos\Downloads\GradProject2 - Copy (2)\clips.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yolos/Downloads/GradProject2%20-%20Copy%20%282%29/clips.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df.head()
#
# NameError: name 'df' is not defined

# %%
import os
import pandas as pd

def main():
    df = pd.read_csv(r'C:\Users\yolos\Downloads\GradProject2 - Copy (2)\RecommendationSystem\dataWithCluster.csv')
    folder_path = r"C:\Users\yolos\Downloads\archive\fma_medium\fma_medium"  # path of FMA_large
    output_folder = os.path.join(r"C:\Users\yolos\OneDrive\Desktop", "Recommendation")

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for folder_name in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, folder_name)
        if os.path.isdir(subfolder_path):
            for filename in os.listdir(subfolder_path):
                if filename.endswith(".mp3"):
                    file_path = os.path.join(subfolder_path, filename)
                    track_id = int(filename[:-4].lstrip('0'))  # Get the track id from the filename
                    if track_id in df['track_id'].tolist():
                        # Move the mp3 file to the "Recommendation" folder
                        new_file_path = os.path.join(output_folder, filename)
                        os.rename(file_path, new_file_path)
                        print("Added:", filename)
                    else:
                        print("Ignored:", filename)

main()
# Out:
# Ignored: 000002.mp3
# Ignored: 000003.mp3
# Ignored: 000136.mp3
# Ignored: 000148.mp3
# Ignored: 000181.mp3
# Ignored: 000182.mp3
# Ignored: 000424.mp3
# Ignored: 000425.mp3
# Ignored: 000458.mp3
# Ignored: 000459.mp3
# Ignored: 000512.mp3
# Ignored: 000590.mp3
# Ignored: 000591.mp3
# Ignored: 000592.mp3
# Ignored: 000593.mp3
# Ignored: 000615.mp3
# Ignored: 000666.mp3
# Ignored: 000667.mp3
# Ignored: 000668.mp3
# Ignored: 000672.mp3
# Ignored: 000674.mp3
# Ignored: 000676.mp3
# Ignored: 000680.mp3
# Ignored: 000684.mp3
# Ignored: 000686.mp3
# Ignored: 000696.mp3
# Ignored: 000698.mp3
# Ignored: 000701.mp3
# Ignored: 000702.mp3
# Ignored: 000703.mp3
# Ignored: 000704.mp3
# Ignored: 000705.mp3
# Ignored: 000706.mp3
# Ignored: 000707.mp3
# Ignored: 000708.mp3
# Ignored: 000709.mp3
# Ignored: 000734.mp3
# Ignored: 000735.mp3
# Ignored: 000736.mp3
# Ignored: 000737.mp3
# Ignored: 000738.mp3
# Ignored: 000739.mp3
# Ignored: 000740.mp3
# Ignored: 000741.mp3
# Ignored: 000742.mp3
# ...
